# %% [markdown]
# ## import itertools

# %%
import itertools

# %%
list1 = [1, 2, 7]
list2 = [4, 5, 6]
combined = itertools.chain(list1, list2)
print(type(combined))
print(list(combined))
# Out:
# <class 'itertools.chain'>
# [1, 2, 7, 4, 5, 6]

# %%
while next(combined):
    print(next(combined))
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 while next(combined):
#       2     print(next(combined))
#
# StopIteration:
